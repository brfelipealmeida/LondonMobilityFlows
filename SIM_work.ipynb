# %% [markdown]
# # **Estimating Mobility Flows for Leisure and Care**
#
#
# ---
# ## MSc Urban Spatial Science
#
# Felipe Almeida
#
# 2023

# %% [markdown]
# # **Load Packages**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
import folium
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats
import numpy as np
from math import sqrt
import requests

# %%
path = '/content/drive/My Drive/Colab/'

# %% [markdown]
# # **Load Data**

# %%
OD = pd.read_csv(path + 'OD_level7_work_new.csv')

JOBS = pd.read_csv(path + 'POI_work7_new.csv')

POP = pd.read_csv(path + 'pop7.csv')

# locomizer hexagon grid at level 8
grid8 = gpd.read_file(path + 'grid7.json')

#London borough
LDN_borough = gpd.read_file(path + 'London_borough.json')

# %%
POP
# Out:
#               _index    population
# 0    87194ac00ffffff  20981.016883
# 1    87194ac01ffffff  20807.055018
# 2    87194ac02ffffff  11696.987362
# 3    87194ac03ffffff  16885.258337
# 4    87194ac04ffffff  21207.271285
# ..               ...           ...
# 410  87195db5bffffff  20305.808018
# 411  87195db5cffffff   1447.818893
# 412  87195db5dffffff  18468.409200
# 413  87195db69ffffff   1980.493846
# 414  87195db6bffffff  10793.091151
#
# [415 rows x 2 columns]

# %%
JOBS.rename(columns={"all":"jobs"}, inplace = True)
JOBS
# Out:
#               _index  jobs
# 0    87194ac00ffffff   268
# 1    87194ac01ffffff   133
# 2    87194ac02ffffff    94
# 3    87194ac03ffffff    85
# 4    87194ac04ffffff   272
# ..               ...   ...
# 410  87195db5bffffff   218
# 411  87195db5cffffff    10
# 412  87195db5dffffff    23
# 413  87195db69ffffff    24
# 414  87195db6bffffff   160
#
# [415 rows x 2 columns]

# %%
OD
# Out:
#             ORIGIN_CODE DESTINATION_CODE   FLOWS
# 0       87194ac00ffffff  87194ac00ffffff  7405.0
# 1       87194ac00ffffff  87194ac01ffffff    42.0
# 2       87194ac00ffffff  87194ac02ffffff    42.0
# 3       87194ac00ffffff  87194ac03ffffff    21.0
# 4       87194ac00ffffff  87194ac04ffffff    42.0
# ...                 ...              ...     ...
# 172220  87195db6bffffff  87195db5bffffff     0.0
# 172221  87195db6bffffff  87195db5cffffff     0.0
# 172222  87195db6bffffff  87195db5dffffff     0.0
# 172223  87195db6bffffff  87195db69ffffff    21.0
# 172224  87195db6bffffff  87195db6bffffff  7946.0
#
# [172225 rows x 3 columns]

# %%
DG_work = pd.read_csv( path + 'DG_work.csv')

# %%
DG_work
# Out:
#            ORIGIN_CODE DESTINATION_CODE  flows
# 0      87195d366ffffff  87194aca5ffffff      1
# 1      87195d366ffffff  87195dacbffffff      3
# 2      87195d366ffffff  87194ada4ffffff      9
# 3      87195d366ffffff  87194ad26ffffff      8
# 4      87195d366ffffff  87195d344ffffff      1
# ...                ...              ...    ...
# 51870  87194e685ffffff  87194ada8ffffff     13
# 51871  87194e685ffffff  87194ad91ffffff     12
# 51872  87194e685ffffff  87194ad81ffffff      4
# 51873  87194e685ffffff  87194ac28ffffff      2
# 51874  87194e685ffffff  87195d36affffff      3
#
# [51875 rows x 3 columns]

# %%
OD = OD.copy()
OD = pd.merge(DG_work, OD, on=['ORIGIN_CODE', 'DESTINATION_CODE'], how= 'inner')
OD.drop(columns=['flows'], inplace=True)

# %%
OD
# Out:
#            ORIGIN_CODE DESTINATION_CODE  FLOWS
# 0      87195d366ffffff  87194aca5ffffff    0.0
# 1      87195d366ffffff  87195dacbffffff    0.0
# 2      87195d366ffffff  87194ada4ffffff    0.0
# 3      87195d366ffffff  87194ad26ffffff    0.0
# 4      87195d366ffffff  87195d344ffffff    0.0
# ...                ...              ...    ...
# 51870  87194e685ffffff  87194ada8ffffff    0.0
# 51871  87194e685ffffff  87194ad91ffffff    0.0
# 51872  87194e685ffffff  87194ad81ffffff    0.0
# 51873  87194e685ffffff  87194ac28ffffff    0.0
# 51874  87194e685ffffff  87195d36affffff    0.0
#
# [51875 rows x 3 columns]

# %% [markdown]
# # **Part 1**

# %%
#transform london to BNG
grid8.to_crs("EPSG:27700", inplace = True)
#We can check that this has occured by plotting the results
grid8.plot(figsize = (10,15), facecolor = "None", edgecolor = "darkgray")
plt.show()

# %%
#order it by borough code - *This step will be important later on*
grid8.sort_values(by=["_index"], inplace = True)

#extract the centroids
grid8["Centroids"] = grid8.geometry.centroid

# %%
# set the index
London = grid8
London.set_index('_index', inplace=True, drop=True)

#calculate distances from all Hex centroids to all Hex centroids
distances = London.rename_axis('Orig').Centroids.apply(lambda x: London.rename_axis('Dest').Centroids.distance(x)).stack().reset_index()
distances.rename(columns = {0:'Dist'}, inplace=True)
distances.sort_values(by=["Orig", "Dest"], inplace = True)
London.reset_index(inplace=True)

London
# Out:
#               _index                                           geometry  \
# 0    87194ac00ffffff  POLYGON ((530198.675 161408.835, 529201.343 16...
# 1    87194ac01ffffff  POLYGON ((531687.078 159487.402, 530689.887 15...
# 2    87194ac02ffffff  POLYGON ((527958.284 161182.457, 526960.606 16...
# 3    87194ac03ffffff  POLYGON ((529446.920 159260.759, 528449.383 15...
# 4    87194ac04ffffff  POLYGON ((530950.217 163556.354, 529953.090 16...
# ..               ...                                                ...
# 410  87195db5bffffff  POLYGON ((525811.072 198212.705, 524814.675 19...
# 411  87195db5cffffff  POLYGON ((527312.727 202492.207, 526316.744 20...
# 412  87195db5dffffff  POLYGON ((528799.155 200573.363, 527803.312 19...
# 413  87195db69ffffff  POLYGON ((537741.407 201455.283, 536746.951 20...
# 414  87195db6bffffff  POLYGON ((535506.795 201234.891, 534511.993 20...
#
#                          Centroids
# 0    POINT (530444.193 160052.310)
# 1    POINT (531932.646 158130.811)
# 2    POINT (528203.746 159825.736)
# 3    POINT (529692.431 157903.971)
# 4    POINT (531195.743 162200.092)
# ..                             ...
# 410  POINT (526056.262 196859.377)
# 411  POINT (527557.932 201139.413)
# 412  POINT (529044.412 199220.499)
# 413  POINT (537986.901 200103.204)
# 414  POINT (535752.230 199882.616)
#
# [415 rows x 3 columns]

# %%
JOBS
# Out:
#               _index  jobs
# 0    87194ac00ffffff   268
# 1    87194ac01ffffff   133
# 2    87194ac02ffffff    94
# 3    87194ac03ffffff    85
# 4    87194ac04ffffff   272
# ..               ...   ...
# 410  87195db5bffffff   218
# 411  87195db5cffffff    10
# 412  87195db5dffffff    23
# 413  87195db69ffffff    24
# 414  87195db6bffffff   160
#
# [415 rows x 2 columns]

# %%
POP
# Out:
#               _index    population
# 0    87194ac00ffffff  20981.016883
# 1    87194ac01ffffff  20807.055018
# 2    87194ac02ffffff  11696.987362
# 3    87194ac03ffffff  16885.258337
# 4    87194ac04ffffff  21207.271285
# ..               ...           ...
# 410  87195db5bffffff  20305.808018
# 411  87195db5cffffff   1447.818893
# 412  87195db5dffffff  18468.409200
# 413  87195db69ffffff   1980.493846
# 414  87195db6bffffff  10793.091151
#
# [415 rows x 2 columns]

# %%
# Merge the two DataFrames based on the common column '_index' and keep all keys
merged_df = pd.merge(JOBS, POP, on='_index', how='outer')

# Replace NaN values with zeros
merged_df = merged_df.fillna(0)

#merge on the origins
OD = OD.merge(merged_df, left_on='ORIGIN_CODE', right_on='_index', how='outer')
OD.drop(columns = ["_index"], inplace = True)
OD.rename(columns={"population":"origpop", "jobs": "origjob"}, inplace = True)

#merge on the destinations
OD = OD.merge(merged_df, left_on='DESTINATION_CODE', right_on='_index', how='outer')
OD.drop(columns = ["_index"], inplace = True)
OD.rename(columns={"population":"destpop", "jobs": "destjobs"}, inplace = True)

# Replace NaN values with zeros
OD = OD.fillna(0)

# Remove rows with value '0' in 'ORIGIN_CODE'
OD = OD[OD['ORIGIN_CODE'] != '0']
OD = OD[OD['DESTINATION_CODE'] != '0']

# Convert 'ORIGIN_CODE' column to string
OD['ORIGIN_CODE'] = OD['ORIGIN_CODE'].astype(str)

# Remove rows with value '0' in 'ORIGIN_CODE'
OD = OD[OD['ORIGIN_CODE'] != '0']

# %%
OD
# Out:
#            ORIGIN_CODE DESTINATION_CODE  FLOWS  origjob       origpop  \
# 0      87195d366ffffff  87194aca5ffffff    0.0      136  12296.155629
# 1      87194ac36ffffff  87194aca5ffffff    0.0      464  25933.631542
# 2      87194e613ffffff  87194aca5ffffff    0.0      221  11959.590258
# 3      87195d368ffffff  87194aca5ffffff    0.0       41   4668.624814
# 4      87195daedffffff  87194aca5ffffff    0.0      422  36449.396125
# ...                ...              ...    ...      ...           ...
# 51870  87195dac1ffffff  87194ac36ffffff    0.0      162  14983.562195
# 51871  87194e693ffffff  87194ac36ffffff    0.0      459  39720.169246
# 51872  87194ad31ffffff  87194ac36ffffff    0.0      608  45731.556616
# 51873  87194ac06ffffff  87194ac36ffffff    0.0       88  21929.957569
# 51874  87194e685ffffff  87194ac36ffffff    0.0      167  25377.392974
#
#        destjobs       destpop
# 0           2.0      0.000000
# 1           2.0      0.000000
# 2           2.0      0.000000
# 3           2.0      0.000000
# 4           2.0      0.000000
# ...         ...           ...
# 51870     464.0  25933.631542
# 51871     464.0  25933.631542
# 51872     464.0  25933.631542
# 51873     464.0  25933.631542
# 51874     464.0  25933.631542
#
# [51875 rows x 7 columns]

# %%
#the data needs to be ordered by borough code, if it's not then we will run into problems when we try to merge the
#distance data back in later
OD.sort_values(by=["ORIGIN_CODE", "DESTINATION_CODE"], inplace = True)

#reset the resulting index (important for later) when merging back together
OD.reset_index(inplace=True)
OD.drop(columns = ["index"], inplace=True)

#first we create a new total column which excludes intra-borough flow totals (we will set them
#to a very small number for reasons you will see later)
OD["TotalNoIntra"] = OD.apply(lambda x: 0 if x['ORIGIN_CODE'] == x['DESTINATION_CODE'] else x['FLOWS'], axis=1)

#set the number to a very small number
OD["offset"]= OD.apply(lambda x: 0.0000000001 if x['ORIGIN_CODE'] == x['DESTINATION_CODE'] else 0, axis=1)

# %%
distances
# Out:
#                    Orig             Dest          Dist
# 0       87194ac00ffffff  87194ac00ffffff      0.000000
# 1       87194ac00ffffff  87194ac01ffffff   2430.565498
# 2       87194ac00ffffff  87194ac02ffffff   2251.874795
# 3       87194ac00ffffff  87194ac03ffffff   2276.072309
# 4       87194ac00ffffff  87194ac04ffffff   2275.476462
# ...                 ...              ...           ...
# 172220  87195db6bffffff  87195db5bffffff  10156.365660
# 172221  87195db6bffffff  87195db5cffffff   8290.118175
# 172222  87195db6bffffff  87195db5dffffff   6740.416649
# 172223  87195db6bffffff  87195db69ffffff   2245.531445
# 172224  87195db6bffffff  87195db6bffffff      0.000000
#
# [172225 rows x 3 columns]

# %%
## ADD DISTANCE INTO THE DATAFRAME

# create a commom index in distance dataframe
distances['combined'] = distances['Orig'] + ',' + distances['Dest']
distances.drop(columns = ['Orig', 'Dest'], inplace=True)

#create a commom index in OD
OD['combined'] = OD['ORIGIN_CODE'] + ',' + OD['DESTINATION_CODE']

#add distance into the dataframe
OD = OD.merge(distances, left_on='combined', right_on='combined', how='inner')

# remove column
OD.drop(columns = ["combined"], inplace = True)

# Convert origpop and destpop columns to integers
OD['origpop'] = OD['origpop'].astype(int)
OD['destpop'] = OD['destpop'].astype(int)
OD['FLOWS'] = OD['FLOWS'].astype(int)
OD['TotalNoIntra'] = OD['TotalNoIntra'].astype(int)
OD
# Out:
#            ORIGIN_CODE DESTINATION_CODE  FLOWS  origjob  origpop  destjobs  \
# 0      87194ac05ffffff  87194ac00ffffff    105      142    20963     268.0
# 1      87194ac05ffffff  87194ac01ffffff     42      142    20963     133.0
# 2      87194ac05ffffff  87194ac02ffffff      0      142    20963      94.0
# 3      87194ac05ffffff  87194ac03ffffff      0      142    20963      85.0
# 4      87194ac05ffffff  87194ac04ffffff    105      142    20963     272.0
# ...                ...              ...    ...      ...      ...       ...
# 51870  87195daf5ffffff  87195db5bffffff      0        8      170     218.0
# 51871  87195daf5ffffff  87195db5cffffff      0        8      170      10.0
# 51872  87195daf5ffffff  87195db5dffffff      0        8      170      23.0
# 51873  87195daf5ffffff  87195db69ffffff      0        8      170      24.0
# 51874  87195daf5ffffff  87195db6bffffff      0        8      170     160.0
#
#        destpop  TotalNoIntra  offset          Dist
# 0        20981           105     0.0   2251.236531
# 1        20807            42     0.0   2275.632369
# 2        11696             0     0.0   4503.111326
# 3        16885             0     0.0   3819.612751
# 4        21207           105     0.0   2430.265954
# ...        ...           ...     ...           ...
# 51870    20305             0     0.0  16844.818926
# 51871     1447             0     0.0  19628.864700
# 51872    18468             0     0.0  20344.802842
# 51873     1980             0     0.0  29201.533495
# 51874    10793             0     0.0  26980.283813
#
# [51875 rows x 10 columns]

# %%
#now chop out the intra-borough flows
OD = OD[OD["ORIGIN_CODE"] != OD["DESTINATION_CODE"]]

# %%
OD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51750 entries, 0 to 51874
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORIGIN_CODE       51750 non-null  object
#  1   DESTINATION_CODE  51750 non-null  object
#  2   FLOWS             51750 non-null  int64
#  3   origjob           51750 non-null  int64
#  4   origpop           51750 non-null  int64
#  5   destjobs          51750 non-null  float64
#  6   destpop           51750 non-null  int64
#  7   TotalNoIntra      51750 non-null  int64
#  8   offset            51750 non-null  float64
#  9   Dist              51750 non-null  float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 4.3+ MB

# %%
#### Create Origin Destination matrix
OD_pivot = pd.pivot_table(OD,
                    values ="FLOWS",
                    index="ORIGIN_CODE",
                    columns = "DESTINATION_CODE",
                    aggfunc=sum,
                    margins=True)
OD_pivot.fillna(0, inplace=True)
OD_pivot = OD_pivot.astype(int)
OD_pivot.sort_values(by='All').tail(10)
OD_pivot
# Out:
# DESTINATION_CODE  87194ac00ffffff  87194ac01ffffff  87194ac02ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff               105               42                0
# 87194ac06ffffff               106                0               42
# 87194ac0effffff                42               21                0
# 87194ac10ffffff                 0                0               21
# 87194ac15ffffff                21                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0               21                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                           505              147              105
#
# DESTINATION_CODE  87194ac03ffffff  87194ac04ffffff  87194ac05ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0              105                0
# 87194ac06ffffff                 0               42                0
# 87194ac0effffff                 0                0                0
# 87194ac10ffffff                 0                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0               21               21
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                            42              441               63
#
# DESTINATION_CODE  87194ac06ffffff  87194ac0cffffff  87194ac0effffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0               21                0
# 87194ac06ffffff                 0                0                0
# 87194ac0effffff                 0               21                0
# 87194ac10ffffff                21                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0                0                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                           189              126               21
#
# DESTINATION_CODE  87194ac10ffffff  ...  87195db4effffff  87195db58ffffff  \
# ORIGIN_CODE                        ...
# 87194ac05ffffff                 0  ...                0                0
# 87194ac06ffffff                 0  ...                0                0
# 87194ac0effffff                 0  ...                0                0
# 87194ac10ffffff                 0  ...                0                0
# 87194ac15ffffff                42  ...                0                0
# ...                           ...  ...              ...              ...
# 87195daebffffff                 0  ...                0                0
# 87195daedffffff                 0  ...                0                0
# 87195daf3ffffff                 0  ...                0                0
# 87195daf5ffffff                 0  ...                0                0
# All                            84  ...               84                0
#
# DESTINATION_CODE  87195db59ffffff  87195db5affffff  87195db5bffffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0                0                0
# 87194ac06ffffff                 0                0                0
# 87194ac0effffff                 0                0                0
# 87194ac10ffffff                 0                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0                0                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                           252               21              441
#
# DESTINATION_CODE  87195db5cffffff  87195db5dffffff  87195db69ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0                0                0
# 87194ac06ffffff                 0                0                0
# 87194ac0effffff                 0                0                0
# 87194ac10ffffff                 0                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0                0                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                            21               42              232
#
# DESTINATION_CODE  87195db6bffffff     All
# ORIGIN_CODE
# 87194ac05ffffff                 0    1429
# 87194ac06ffffff                 0     947
# 87194ac0effffff                 0     210
# 87194ac10ffffff                 0    1072
# 87194ac15ffffff                 0     694
# ...                           ...     ...
# 87195daebffffff                 0    2731
# 87195daedffffff                 0    4644
# 87195daf3ffffff                 0     189
# 87195daf5ffffff                 0     548
# All                           420  305794
#
# [126 rows x 416 columns]

# %%
OD
# Out:
#            ORIGIN_CODE DESTINATION_CODE  FLOWS  origjob  origpop  destjobs  \
# 0      87194ac05ffffff  87194ac00ffffff    105      142    20963     268.0
# 1      87194ac05ffffff  87194ac01ffffff     42      142    20963     133.0
# 2      87194ac05ffffff  87194ac02ffffff      0      142    20963      94.0
# 3      87194ac05ffffff  87194ac03ffffff      0      142    20963      85.0
# 4      87194ac05ffffff  87194ac04ffffff    105      142    20963     272.0
# ...                ...              ...    ...      ...      ...       ...
# 51870  87195daf5ffffff  87195db5bffffff      0        8      170     218.0
# 51871  87195daf5ffffff  87195db5cffffff      0        8      170      10.0
# 51872  87195daf5ffffff  87195db5dffffff      0        8      170      23.0
# 51873  87195daf5ffffff  87195db69ffffff      0        8      170      24.0
# 51874  87195daf5ffffff  87195db6bffffff      0        8      170     160.0
#
#        destpop  TotalNoIntra  offset          Dist
# 0        20981           105     0.0   2251.236531
# 1        20807            42     0.0   2275.632369
# 2        11696             0     0.0   4503.111326
# 3        16885             0     0.0   3819.612751
# 4        21207           105     0.0   2430.265954
# ...        ...           ...     ...           ...
# 51870    20305             0     0.0  16844.818926
# 51871     1447             0     0.0  19628.864700
# 51872    18468             0     0.0  20344.802842
# 51873     1980             0     0.0  29201.533495
# 51874    10793             0     0.0  26980.283813
#
# [51750 rows x 10 columns]

# %% [markdown]
# # **Part 2**

# %%
#take the variables and produce logarithms of them
x_variables = ["destpop", "destjobs", "Dist"]
log_x_vars = []
for x in x_variables:
    OD[f"log_{x}"] = np.log(OD[x]+1)
    log_x_vars.append(f"log_{x}")
# Out:
# <ipython-input-26-857f0a8b48bf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OD[f"log_{x}"] = np.log(OD[x]+1)
# <ipython-input-26-857f0a8b48bf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OD[f"log_{x}"] = np.log(OD[x]+1)
# <ipython-input-26-857f0a8b48bf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OD[f"log_{x}"] = np.log(OD[x]+1)

# %%
#create the formula (the "-1" indicates no intercept in the regression model).
formula = 'FLOWS ~ ORIGIN_CODE + log_destjobs + log_Dist-1'
#run a production constrained sim
prodSim = smf.glm(formula = formula, data=OD, family=sm.families.Poisson()).fit()
#let's have a look at it's summary
print(prodSim.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  FLOWS   No. Observations:                51750
# Model:                            GLM   Df Residuals:                    51623
# Model Family:                 Poisson   Df Model:                          126
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -2.9501e+05
# Date:                Thu, 07 Sep 2023   Deviance:                   5.5572e+05
# Time:                        09:57:57   Pearson chi2:                 4.00e+06
# No. Iterations:                    29   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ORIGIN_CODE[87194ac05ffffff]    12.4930      0.037    339.523      0.000      12.421      12.565
# ORIGIN_CODE[87194ac06ffffff]    11.8787      0.041    287.570      0.000      11.798      11.960
# ORIGIN_CODE[87194ac0effffff]    11.0962      0.074    150.207      0.000      10.951      11.241
# ORIGIN_CODE[87194ac10ffffff]    12.2596      0.040    305.779      0.000      12.181      12.338
# ORIGIN_CODE[87194ac15ffffff]    11.6835      0.046    254.839      0.000      11.594      11.773
# ORIGIN_CODE[87194ac16ffffff]    12.1616      0.039    309.480      0.000      12.085      12.239
# ORIGIN_CODE[87194ac20ffffff]    12.0367      0.037    322.527      0.000      11.964      12.110
# ORIGIN_CODE[87194ac30ffffff]    13.2037      0.029    450.304      0.000      13.146      13.261
# ORIGIN_CODE[87194ac32ffffff]    13.0278      0.030    431.045      0.000      12.969      13.087
# ORIGIN_CODE[87194ac36ffffff]    13.0910      0.030    442.515      0.000      13.033      13.149
# ORIGIN_CODE[87194ac84ffffff]    10.2962      0.112     91.638      0.000      10.076      10.516
# ORIGIN_CODE[87194aca2ffffff]    10.9474      0.074    148.238      0.000      10.803      11.092
# ORIGIN_CODE[87194aca6ffffff]    12.0894      0.042    284.664      0.000      12.006      12.173
# ORIGIN_CODE[87194ad09ffffff]    12.6595      0.033    387.748      0.000      12.596      12.723
# ORIGIN_CODE[87194ad0bffffff]    12.3836      0.034    362.363      0.000      12.317      12.451
# ORIGIN_CODE[87194ad0effffff]    12.7229      0.031    413.554      0.000      12.663      12.783
# ORIGIN_CODE[87194ad12ffffff]    12.8008      0.029    434.366      0.000      12.743      12.859
# ORIGIN_CODE[87194ad16ffffff]    12.7262      0.029    432.325      0.000      12.668      12.784
# ORIGIN_CODE[87194ad1affffff]    13.3109      0.029    466.785      0.000      13.255      13.367
# ORIGIN_CODE[87194ad21ffffff]    12.7394      0.031    416.253      0.000      12.679      12.799
# ORIGIN_CODE[87194ad24ffffff]    13.1138      0.029    453.058      0.000      13.057      13.171
# ORIGIN_CODE[87194ad25ffffff]    12.4399      0.032    387.134      0.000      12.377      12.503
# ORIGIN_CODE[87194ad2affffff]    13.0628      0.029    443.685      0.000      13.005      13.120
# ORIGIN_CODE[87194ad2bffffff]    12.7635      0.031    408.872      0.000      12.702      12.825
# ORIGIN_CODE[87194ad2cffffff]    12.9204      0.030    427.652      0.000      12.861      12.980
# ORIGIN_CODE[87194ad2dffffff]    12.7177      0.032    399.308      0.000      12.655      12.780
# ORIGIN_CODE[87194ad31ffffff]    12.9106      0.029    445.235      0.000      12.854      12.967
# ORIGIN_CODE[87194ad33ffffff]    13.1771      0.028    465.883      0.000      13.122      13.233
# ORIGIN_CODE[87194ad40ffffff]   -15.5312   2.41e+04     -0.001      0.999   -4.73e+04    4.73e+04
# ORIGIN_CODE[87194ad44ffffff]    12.6736      0.038    333.971      0.000      12.599      12.748
# ORIGIN_CODE[87194ad46ffffff]    12.4303      0.039    317.352      0.000      12.353      12.507
# ORIGIN_CODE[87194ad51ffffff]    10.6257      0.081    130.614      0.000      10.466      10.785
# ORIGIN_CODE[87194ad53ffffff]    11.5844      0.053    217.537      0.000      11.480      11.689
# ORIGIN_CODE[87194ad55ffffff]     9.7673      0.112     87.147      0.000       9.548       9.987
# ORIGIN_CODE[87194ad59ffffff]    11.1379      0.087    128.334      0.000      10.968      11.308
# ORIGIN_CODE[87194ad5affffff]     9.6024      0.157     61.333      0.000       9.296       9.909
# ORIGIN_CODE[87194ad64ffffff]    12.7836      0.038    335.510      0.000      12.709      12.858
# ORIGIN_CODE[87194ad70ffffff]    12.1596      0.038    317.702      0.000      12.085      12.235
# ORIGIN_CODE[87194ad73ffffff]    12.2398      0.039    316.387      0.000      12.164      12.316
# ORIGIN_CODE[87194ad81ffffff]    10.8500      0.053    204.265      0.000      10.746      10.954
# ORIGIN_CODE[87194ad82ffffff]    11.8376      0.038    308.067      0.000      11.762      11.913
# ORIGIN_CODE[87194ad86ffffff]    12.2999      0.034    364.752      0.000      12.234      12.366
# ORIGIN_CODE[87194ad89ffffff]    12.9194      0.031    411.205      0.000      12.858      12.981
# ORIGIN_CODE[87194ad8affffff]    12.5172      0.034    369.449      0.000      12.451      12.584
# ORIGIN_CODE[87194ad8cffffff]    12.5191      0.033    383.152      0.000      12.455      12.583
# ORIGIN_CODE[87194ad90ffffff]    13.4815      0.029    470.922      0.000      13.425      13.538
# ORIGIN_CODE[87194ad91ffffff]    12.5512      0.033    380.443      0.000      12.487      12.616
# ORIGIN_CODE[87194ad93ffffff]    12.7335      0.032    393.472      0.000      12.670      12.797
# ORIGIN_CODE[87194ad98ffffff]    10.6552      0.064    167.319      0.000      10.530      10.780
# ORIGIN_CODE[87194ad9dffffff]    13.2609      0.030    442.467      0.000      13.202      13.320
# ORIGIN_CODE[87194ada4ffffff]    12.7944      0.029    433.750      0.000      12.737      12.852
# ORIGIN_CODE[87194ada6ffffff]    13.0921      0.029    454.638      0.000      13.036      13.148
# ORIGIN_CODE[87194adabffffff]    12.7271      0.031    410.340      0.000      12.666      12.788
# ORIGIN_CODE[87194adacffffff]    12.8027      0.030    429.613      0.000      12.744      12.861
# ORIGIN_CODE[87194adb6ffffff]    12.8253      0.031    418.132      0.000      12.765      12.885
# ORIGIN_CODE[87194e602ffffff]    13.9196      0.030    467.721      0.000      13.861      13.978
# ORIGIN_CODE[87194e603ffffff]    11.4579      0.056    204.218      0.000      11.348      11.568
# ORIGIN_CODE[87194e606ffffff]    11.6827      0.058    202.806      0.000      11.570      11.796
# ORIGIN_CODE[87194e60affffff]    12.1702      0.045    271.244      0.000      12.082      12.258
# ORIGIN_CODE[87194e60bffffff]    10.2261      0.112     91.163      0.000      10.006      10.446
# ORIGIN_CODE[87194e60dffffff]   -15.1521   2.49e+04     -0.001      1.000   -4.88e+04    4.88e+04
# ORIGIN_CODE[87194e610ffffff]    11.6362      0.053    218.621      0.000      11.532      11.740
# ORIGIN_CODE[87194e613ffffff]    13.5079      0.030    446.142      0.000      13.449      13.567
# ORIGIN_CODE[87194e615ffffff]    12.3811      0.042    291.814      0.000      12.298      12.464
# ORIGIN_CODE[87194e616ffffff]     8.7213      0.220     39.677      0.000       8.291       9.152
# ORIGIN_CODE[87194e61affffff]    13.1260      0.031    428.835      0.000      13.066      13.186
# ORIGIN_CODE[87194e61cffffff]    13.2536      0.031    424.461      0.000      13.192      13.315
# ORIGIN_CODE[87194e61effffff]    13.7071      0.029    472.669      0.000      13.650      13.764
# ORIGIN_CODE[87194e680ffffff]    12.7169      0.032    399.066      0.000      12.654      12.779
# ORIGIN_CODE[87194e685ffffff]    13.1889      0.030    438.007      0.000      13.130      13.248
# ORIGIN_CODE[87194e693ffffff]    13.0372      0.029    445.118      0.000      12.980      13.095
# ORIGIN_CODE[87194e694ffffff]    12.6587      0.032    392.996      0.000      12.596      12.722
# ORIGIN_CODE[87194e696ffffff]    13.1557      0.030    444.945      0.000      13.098      13.214
# ORIGIN_CODE[87194e698ffffff]    12.2086      0.033    374.040      0.000      12.145      12.273
# ORIGIN_CODE[87194e69bffffff]    12.9624      0.029    446.559      0.000      12.905      13.019
# ORIGIN_CODE[87194e69dffffff]    13.4324      0.028    476.801      0.000      13.377      13.488
# ORIGIN_CODE[87194e69effffff]    12.0881      0.034    360.397      0.000      12.022      12.154
# ORIGIN_CODE[87194e6a3ffffff]    12.8157      0.034    380.903      0.000      12.750      12.882
# ORIGIN_CODE[87194e6a5ffffff]     9.2892      0.157     59.345      0.000       8.982       9.596
# ORIGIN_CODE[87194e6a9ffffff]    13.7134      0.028    485.616      0.000      13.658      13.769
# ORIGIN_CODE[87194e6acffffff]    10.8952      0.062    176.388      0.000      10.774      11.016
# ORIGIN_CODE[87194e6aeffffff]    12.3088      0.037    334.503      0.000      12.237      12.381
# ORIGIN_CODE[87194e6b5ffffff]    11.7545      0.049    240.493      0.000      11.659      11.850
# ORIGIN_CODE[87194e6b6ffffff]    12.4534      0.038    328.451      0.000      12.379      12.528
# ORIGIN_CODE[87194e6c0ffffff]    13.5032      0.030    450.278      0.000      13.444      13.562
# ORIGIN_CODE[87194e6c1ffffff]    13.1924      0.033    395.973      0.000      13.127      13.258
# ORIGIN_CODE[87194e6c3ffffff]    12.9105      0.033    387.887      0.000      12.845      12.976
# ORIGIN_CODE[87194e6c4ffffff]    11.9040      0.044    270.467      0.000      11.818      11.990
# ORIGIN_CODE[87194e6c5ffffff]    11.8003      0.049    239.429      0.000      11.704      11.897
# ORIGIN_CODE[87194e6d3ffffff]    12.0162      0.037    327.356      0.000      11.944      12.088
# ORIGIN_CODE[87194e6d9ffffff]    10.6678      0.074    144.887      0.000      10.523      10.812
# ORIGIN_CODE[87194e6dcffffff]    13.1034      0.031    423.717      0.000      13.043      13.164
# ORIGIN_CODE[87195d360ffffff]    12.1702      0.040    304.879      0.000      12.092      12.248
# ORIGIN_CODE[87195d361ffffff]    12.9304      0.033    396.155      0.000      12.866      12.994
# ORIGIN_CODE[87195d365ffffff]    12.4687      0.035    356.822      0.000      12.400      12.537
# ORIGIN_CODE[87195d366ffffff]    12.1564      0.041    296.801      0.000      12.076      12.237
# ORIGIN_CODE[87195d368ffffff]    12.4608      0.039    323.295      0.000      12.385      12.536
# ORIGIN_CODE[87195d369ffffff]    11.4559      0.055    207.187      0.000      11.348      11.564
# ORIGIN_CODE[87195d36affffff]    12.2483      0.045    273.284      0.000      12.161      12.336
# ORIGIN_CODE[87195da0bffffff]    10.9056      0.066    165.887      0.000      10.777      11.034
# ORIGIN_CODE[87195da0dffffff]    13.1408      0.034    391.403      0.000      13.075      13.207
# ORIGIN_CODE[87195da40ffffff]    12.4532      0.032    388.607      0.000      12.390      12.516
# ORIGIN_CODE[87195da45ffffff]    12.0257      0.034    348.632      0.000      11.958      12.093
# ORIGIN_CODE[87195da4cffffff]    12.6571      0.030    423.853      0.000      12.599      12.716
# ORIGIN_CODE[87195da4effffff]    13.0150      0.029    449.830      0.000      12.958      13.072
# ORIGIN_CODE[87195da51ffffff]    12.2949      0.034    366.181      0.000      12.229      12.361
# ORIGIN_CODE[87195da52ffffff]    13.2760      0.029    450.306      0.000      13.218      13.334
# ORIGIN_CODE[87195da53ffffff]    12.8307      0.031    416.519      0.000      12.770      12.891
# ORIGIN_CODE[87195da61ffffff]    12.9860      0.030    437.084      0.000      12.928      13.044
# ORIGIN_CODE[87195da63ffffff]    12.4395      0.032    384.964      0.000      12.376      12.503
# ORIGIN_CODE[87195da66ffffff]    12.7708      0.032    396.740      0.000      12.708      12.834
# ORIGIN_CODE[87195da69ffffff]    12.6902      0.030    427.310      0.000      12.632      12.748
# ORIGIN_CODE[87195da6affffff]    12.6378      0.030    416.885      0.000      12.578      12.697
# ORIGIN_CODE[87195da70ffffff]    11.5593      0.046    252.474      0.000      11.470      11.649
# ORIGIN_CODE[87195da73ffffff]    12.3982      0.035    357.904      0.000      12.330      12.466
# ORIGIN_CODE[87195dac1ffffff]    12.2365      0.037    332.908      0.000      12.164      12.309
# ORIGIN_CODE[87195dacaffffff]    13.2486      0.030    439.184      0.000      13.190      13.308
# ORIGIN_CODE[87195dad4ffffff]    10.8581      0.087    125.446      0.000      10.688      11.028
# ORIGIN_CODE[87195dadaffffff]    10.9046      0.073    148.406      0.000      10.761      11.049
# ORIGIN_CODE[87195dae0ffffff]    12.0590      0.041    293.441      0.000      11.978      12.140
# ORIGIN_CODE[87195dae1ffffff]    13.0711      0.031    425.966      0.000      13.011      13.131
# ORIGIN_CODE[87195daebffffff]    12.6660      0.032    397.952      0.000      12.604      12.728
# ORIGIN_CODE[87195daedffffff]    13.1377      0.029    446.077      0.000      13.080      13.195
# ORIGIN_CODE[87195daf3ffffff]    10.8360      0.077    140.490      0.000      10.685      10.987
# ORIGIN_CODE[87195daf5ffffff]    11.8891      0.050    237.892      0.000      11.791      11.987
# log_destjobs                     0.9510      0.003    316.447      0.000       0.945       0.957
# log_Dist                        -1.7261      0.002   -754.782      0.000      -1.731      -1.722
# ================================================================================================

# %%
unique_strings2 = OD['ORIGIN_CODE'].unique()

# %%
unique_strings2
# Out:
# array(['87194ac05ffffff', '87194ac06ffffff', '87194ac0effffff',
#        '87194ac10ffffff', '87194ac15ffffff', '87194ac16ffffff',
#        '87194ac20ffffff', '87194ac30ffffff', '87194ac32ffffff',
#        '87194ac36ffffff', '87194ac84ffffff', '87194aca2ffffff',
#        '87194aca6ffffff', '87194ad09ffffff', '87194ad0bffffff',
#        '87194ad0effffff', '87194ad12ffffff', '87194ad16ffffff',
#        '87194ad1affffff', '87194ad21ffffff', '87194ad24ffffff',
#        '87194ad25ffffff', '87194ad2affffff', '87194ad2bffffff',
#        '87194ad2cffffff', '87194ad2dffffff', '87194ad31ffffff',
#        '87194ad33ffffff', '87194ad40ffffff', '87194ad44ffffff',
#        '87194ad46ffffff', '87194ad51ffffff', '87194ad53ffffff',
#        '87194ad55ffffff', '87194ad59ffffff', '87194ad5affffff',
#        '87194ad64ffffff', '87194ad70ffffff', '87194ad73ffffff',
#        '87194ad81ffffff', '87194ad82ffffff', '87194ad86ffffff',
#        '87194ad89ffffff', '87194ad8affffff', '87194ad8cffffff',
#        '87194ad90ffffff', '87194ad91ffffff', '87194ad93ffffff',
#        '87194ad98ffffff', '87194ad9dffffff', '87194ada4ffffff',
#        '87194ada6ffffff', '87194adabffffff', '87194adacffffff',
#        '87194adb6ffffff', '87194e602ffffff', '87194e603ffffff',
#        '87194e606ffffff', '87194e60affffff', '87194e60bffffff',
#        '87194e60dffffff', '87194e610ffffff', '87194e613ffffff',
#        '87194e615ffffff', '87194e616ffffff', '87194e61affffff',
#        '87194e61cffffff', '87194e61effffff', '87194e680ffffff',
#        '87194e685ffffff', '87194e693ffffff', '87194e694ffffff',
#        '87194e696ffffff', '87194e698ffffff', '87194e69bffffff',
#        '87194e69dffffff', '87194e69effffff', '87194e6a3ffffff',
#        '87194e6a5ffffff', '87194e6a9ffffff', '87194e6acffffff',
#        '87194e6aeffffff', '87194e6b5ffffff', '87194e6b6ffffff',
#        '87194e6c0ffffff', '87194e6c1ffffff', '87194e6c3ffffff',
#        '87194e6c4ffffff', '87194e6c5ffffff', '87194e6d3ffffff',
#        '87194e6d9ffffff', '87194e6dcffffff', '87195d360ffffff',
#        '87195d361ffffff', '87195d365ffffff', '87195d366ffffff',
#        '87195d368ffffff', '87195d369ffffff', '87195d36affffff',
#        '87195da0bffffff', '87195da0dffffff', '87195da40ffffff',
#        '87195da45ffffff', '87195da4cffffff', '87195da4effffff',
#        '87195da51ffffff', '87195da52ffffff', '87195da53ffffff',
#        '87195da61ffffff', '87195da63ffffff', '87195da66ffffff',
#        '87195da69ffffff', '87195da6affffff', '87195da70ffffff',
#        '87195da73ffffff', '87195dac1ffffff', '87195dacaffffff',
#        '87195dad4ffffff', '87195dadaffffff', '87195dae0ffffff',
#        '87195dae1ffffff', '87195daebffffff', '87195daedffffff',
#        '87195daf3ffffff', '87195daf5ffffff'], dtype=object)

# %%
count_total2 = len(unique_strings2)
print(count_total2)
# Out:
# 125

# %%
prodSim.params[126]
# Out:
# -1.7260674395043865

# %%
#create some Oi and Dj columns in the dataframe and store row and column totals in them:
#to create O_i, take cdatasub ...then... group by origcodenew ...then... summarise by calculating the sum of Total
O_i = pd.DataFrame(OD.groupby(["ORIGIN_CODE"])["FLOWS"].agg(np.sum))
O_i.rename(columns={"FLOWS":"O_i"}, inplace = True)
OD = OD.merge(O_i, on = "ORIGIN_CODE", how = "left" )

D_j = pd.DataFrame(OD.groupby(["DESTINATION_CODE"])["FLOWS"].agg(np.sum))
D_j.rename(columns={"FLOWS":"D_j"}, inplace = True)
OD = OD.merge(D_j, on = "DESTINATION_CODE", how = "left" )

# %%
#We can do this by pulling out the parameter values
coefs = pd.DataFrame(prodSim.params)
coefs.reset_index(inplace=True)
coefs.rename(columns = {0:"alpha_i", "index":"coef"}, inplace = True)
to_repl = ["(ORIGIN_CODE)", "\[", "\]"]
for x in to_repl:
    coefs["coef"] = coefs["coef"].str.replace(x, "")
#then once you have done this you can join them back into the dataframes
OD = OD.merge(coefs, left_on="ORIGIN_CODE", right_on="coef", how = "left")
OD.drop(columns = ["coef"], inplace = True)
#check this has worked
OD.head()
# Out:
# <ipython-input-34-19ff58c5147f>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   coefs["coef"] = coefs["coef"].str.replace(x, "")
#        ORIGIN_CODE DESTINATION_CODE  FLOWS  origjob  origpop  destjobs  \
# 0  87194ac05ffffff  87194ac00ffffff    105      142    20963     268.0
# 1  87194ac05ffffff  87194ac01ffffff     42      142    20963     133.0
# 2  87194ac05ffffff  87194ac02ffffff      0      142    20963      94.0
# 3  87194ac05ffffff  87194ac03ffffff      0      142    20963      85.0
# 4  87194ac05ffffff  87194ac04ffffff    105      142    20963     272.0
#
#    destpop  TotalNoIntra  offset         Dist  log_destpop  log_destjobs  \
# 0    20981           105     0.0  2251.236531     9.951420      5.594711
# 1    20807            42     0.0  2275.632369     9.943093      4.897840
# 2    11696             0     0.0  4503.111326     9.367088      4.553877
# 3    16885             0     0.0  3819.612751     9.734240      4.454347
# 4    21207           105     0.0  2430.265954     9.962134      5.609472
#
#    log_Dist   O_i  D_j    alpha_i
# 0  7.719679  1429  505  12.492951
# 1  7.730453  1429  147  12.492951
# 2  8.412746  1429  105  12.492951
# 3  8.248166  1429   42  12.492951
# 4  7.796167  1429  441  12.492951

# %%
alpha_i = prodSim.params[0:124]
gamma = prodSim.params[125]
beta = -prodSim.params[126]

# %%
alpha_i
# Out:
# ORIGIN_CODE[87194ac05ffffff]    12.492951
# ORIGIN_CODE[87194ac06ffffff]    11.878652
# ORIGIN_CODE[87194ac0effffff]    11.096162
# ORIGIN_CODE[87194ac10ffffff]    12.259606
# ORIGIN_CODE[87194ac15ffffff]    11.683500
#                                   ...
# ORIGIN_CODE[87195dae0ffffff]    12.059022
# ORIGIN_CODE[87195dae1ffffff]    13.071135
# ORIGIN_CODE[87195daebffffff]    12.666009
# ORIGIN_CODE[87195daedffffff]    13.137661
# ORIGIN_CODE[87195daf3ffffff]    10.836025
# Length: 124, dtype: float64

# %%
gamma
# Out:
# 0.9509567470603426

# %%
OD["prodsimest1"] = np.exp(OD["alpha_i"]+gamma*OD["log_destjobs"]
                                 - beta*OD["log_Dist"])
#or you could do it the easy way like we did last week with the fitted column (See previous practical)
OD.head(10)
# Out:
#        ORIGIN_CODE DESTINATION_CODE  FLOWS  origjob  origpop  destjobs  \
# 0  87194ac05ffffff  87194ac00ffffff    105      142    20963     268.0
# 1  87194ac05ffffff  87194ac01ffffff     42      142    20963     133.0
# 2  87194ac05ffffff  87194ac02ffffff      0      142    20963      94.0
# 3  87194ac05ffffff  87194ac03ffffff      0      142    20963      85.0
# 4  87194ac05ffffff  87194ac04ffffff    105      142    20963     272.0
# 5  87194ac05ffffff  87194ac06ffffff      0      142    20963      88.0
# 6  87194ac05ffffff  87194ac0cffffff     21      142    20963       5.0
# 7  87194ac05ffffff  87194ac0effffff      0      142    20963      18.0
# 8  87194ac05ffffff  87194ac10ffffff      0      142    20963      65.0
# 9  87194ac05ffffff  87194ac12ffffff      0      142    20963       0.0
#
#    destpop  TotalNoIntra  offset          Dist  log_destpop  log_destjobs  \
# 0    20981           105     0.0   2251.236531     9.951420      5.594711
# 1    20807            42     0.0   2275.632369     9.943093      4.897840
# 2    11696             0     0.0   4503.111326     9.367088      4.553877
# 3    16885             0     0.0   3819.612751     9.734240      4.454347
# 4    21207           105     0.0   2430.265954     9.962134      5.609472
# 5    21929             0     0.0   4095.529036     9.995611      4.488636
# 6      182            21     0.0   4135.685824     5.209486      1.791759
# 7     6514             0     0.0   4551.860219     8.781862      2.944439
# 8    12176             0     0.0   8303.762292     9.407304      4.189655
# 9        0             0     0.0  10501.507581     0.000000      0.000000
#
#    log_Dist   O_i  D_j    alpha_i  prodsimest1
# 0  7.719679  1429  505  12.492951    88.996163
# 1  7.730453  1429  147  12.492951    45.028814
# 2  8.412746  1429  105  12.492951     9.999394
# 3  8.248166  1429   42  12.492951    12.084843
# 4  7.796167  1429  441  12.492951    79.091524
# 5  8.317895  1429  189  12.492951    11.069594
# 6  8.327650  1429  126  12.492951     0.837571
# 7  8.423511  1429   21  12.492951     2.124290
# 8  9.024584  1429   84  12.492951     2.459826
# 9  9.259369  1429  252  12.492951     0.030521

# %%
#first round the estimates
OD["prodsimest1"] = round(OD["prodsimest1"],0)
#now we can create a pivot tabel to turn the paired list into a matrix, and compute the margins as well
OD2_pivot = OD.pivot_table(values ="prodsimest1", index="ORIGIN_CODE", columns = "DESTINATION_CODE",
                            aggfunc=np.sum, margins=True)
OD2_pivot
# Out:
# DESTINATION_CODE  87194ac00ffffff  87194ac01ffffff  87194ac02ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff              89.0             45.0             10.0
# 87194ac06ffffff              42.0              7.0             18.0
# 87194ac0effffff               8.0             11.0              2.0
# 87194ac10ffffff              12.0              4.0              9.0
# 87194ac15ffffff              14.0              3.0             13.0
# ...                           ...              ...              ...
# 87195daebffffff               1.0              1.0              1.0
# 87195daedffffff               2.0              1.0              1.0
# 87195daf3ffffff               0.0              0.0              0.0
# 87195daf5ffffff               0.0              0.0              0.0
# All                         486.0            201.0            174.0
#
# DESTINATION_CODE  87194ac03ffffff  87194ac04ffffff  87194ac05ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff              12.0             79.0              NaN
# 87194ac06ffffff               6.0             49.0              9.0
# 87194ac0effffff               7.0              4.0              4.0
# 87194ac10ffffff               4.0             11.0              4.0
# 87194ac15ffffff               4.0             12.0              4.0
# ...                           ...              ...              ...
# 87195daebffffff               0.0              1.0              1.0
# 87195daedffffff               1.0              2.0              1.0
# 87195daf3ffffff               0.0              0.0              0.0
# 87195daf5ffffff               0.0              0.0              0.0
# All                         114.0            569.0            195.0
#
# DESTINATION_CODE  87194ac06ffffff  87194ac0cffffff  87194ac0effffff  \
# ORIGIN_CODE
# 87194ac05ffffff              11.0              1.0              2.0
# 87194ac06ffffff               NaN              0.0              1.0
# 87194ac0effffff               1.0              1.0              NaN
# 87194ac10ffffff               7.0              0.0              1.0
# 87194ac15ffffff              14.0              0.0              0.0
# ...                           ...              ...              ...
# 87195daebffffff               1.0              0.0              0.0
# 87195daedffffff               1.0              0.0              0.0
# 87195daf3ffffff               0.0              0.0              0.0
# 87195daf5ffffff               0.0              0.0              0.0
# All                         181.0              2.0              9.0
#
# DESTINATION_CODE  87194ac10ffffff  ...  87195db4effffff  87195db58ffffff  \
# ORIGIN_CODE                        ...
# 87194ac05ffffff               2.0  ...              0.0              0.0
# 87194ac06ffffff               4.0  ...              0.0              0.0
# 87194ac0effffff               1.0  ...              0.0              0.0
# 87194ac10ffffff               NaN  ...              0.0              0.0
# 87194ac15ffffff              10.0  ...              0.0              0.0
# ...                           ...  ...              ...              ...
# 87195daebffffff               0.0  ...              0.0              1.0
# 87195daedffffff               1.0  ...              1.0              1.0
# 87195daf3ffffff               0.0  ...              0.0              0.0
# 87195daf5ffffff               0.0  ...              0.0              0.0
# All                         132.0  ...             78.0             69.0
#
# DESTINATION_CODE  87195db59ffffff  87195db5affffff  87195db5bffffff  \
# ORIGIN_CODE
# 87194ac05ffffff               0.0              0.0              1.0
# 87194ac06ffffff               0.0              0.0              0.0
# 87194ac0effffff               0.0              0.0              0.0
# 87194ac10ffffff               0.0              0.0              0.0
# 87194ac15ffffff               0.0              0.0              0.0
# ...                           ...              ...              ...
# 87195daebffffff               1.0              0.0              3.0
# 87195daedffffff               2.0              1.0              6.0
# 87195daf3ffffff               0.0              0.0              0.0
# 87195daf5ffffff               0.0              0.0              1.0
# All                         178.0             14.0            387.0
#
# DESTINATION_CODE  87195db5cffffff  87195db5dffffff  87195db69ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff               0.0              0.0              0.0
# 87194ac06ffffff               0.0              0.0              0.0
# 87194ac0effffff               0.0              0.0              0.0
# 87194ac10ffffff               0.0              0.0              0.0
# 87194ac15ffffff               0.0              0.0              0.0
# ...                           ...              ...              ...
# 87195daebffffff               0.0              0.0              0.0
# 87195daedffffff               0.0              0.0              0.0
# 87195daf3ffffff               0.0              0.0              0.0
# 87195daf5ffffff               0.0              0.0              0.0
# All                           3.0             22.0             26.0
#
# DESTINATION_CODE  87195db6bffffff       All
# ORIGIN_CODE
# 87194ac05ffffff               0.0    1425.0
# 87194ac06ffffff               0.0     939.0
# 87194ac0effffff               0.0     172.0
# 87194ac10ffffff               0.0    1057.0
# 87194ac15ffffff               0.0     668.0
# ...                           ...       ...
# 87195daebffffff               1.0    2726.0
# 87195daedffffff               2.0    4651.0
# 87195daf3ffffff               0.0     155.0
# 87195daf5ffffff               0.0     524.0
# All                         233.0  304227.0
#
# [126 rows x 416 columns]

# %%
OD_pivot
# Out:
# DESTINATION_CODE  87194ac00ffffff  87194ac01ffffff  87194ac02ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff               105               42                0
# 87194ac06ffffff               106                0               42
# 87194ac0effffff                42               21                0
# 87194ac10ffffff                 0                0               21
# 87194ac15ffffff                21                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0               21                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                           505              147              105
#
# DESTINATION_CODE  87194ac03ffffff  87194ac04ffffff  87194ac05ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0              105                0
# 87194ac06ffffff                 0               42                0
# 87194ac0effffff                 0                0                0
# 87194ac10ffffff                 0                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0               21               21
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                            42              441               63
#
# DESTINATION_CODE  87194ac06ffffff  87194ac0cffffff  87194ac0effffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0               21                0
# 87194ac06ffffff                 0                0                0
# 87194ac0effffff                 0               21                0
# 87194ac10ffffff                21                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0                0                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                           189              126               21
#
# DESTINATION_CODE  87194ac10ffffff  ...  87195db4effffff  87195db58ffffff  \
# ORIGIN_CODE                        ...
# 87194ac05ffffff                 0  ...                0                0
# 87194ac06ffffff                 0  ...                0                0
# 87194ac0effffff                 0  ...                0                0
# 87194ac10ffffff                 0  ...                0                0
# 87194ac15ffffff                42  ...                0                0
# ...                           ...  ...              ...              ...
# 87195daebffffff                 0  ...                0                0
# 87195daedffffff                 0  ...                0                0
# 87195daf3ffffff                 0  ...                0                0
# 87195daf5ffffff                 0  ...                0                0
# All                            84  ...               84                0
#
# DESTINATION_CODE  87195db59ffffff  87195db5affffff  87195db5bffffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0                0                0
# 87194ac06ffffff                 0                0                0
# 87194ac0effffff                 0                0                0
# 87194ac10ffffff                 0                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0                0                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                           252               21              441
#
# DESTINATION_CODE  87195db5cffffff  87195db5dffffff  87195db69ffffff  \
# ORIGIN_CODE
# 87194ac05ffffff                 0                0                0
# 87194ac06ffffff                 0                0                0
# 87194ac0effffff                 0                0                0
# 87194ac10ffffff                 0                0                0
# 87194ac15ffffff                 0                0                0
# ...                           ...              ...              ...
# 87195daebffffff                 0                0                0
# 87195daedffffff                 0                0                0
# 87195daf3ffffff                 0                0                0
# 87195daf5ffffff                 0                0                0
# All                            21               42              232
#
# DESTINATION_CODE  87195db6bffffff     All
# ORIGIN_CODE
# 87194ac05ffffff                 0    1429
# 87194ac06ffffff                 0     947
# 87194ac0effffff                 0     210
# 87194ac10ffffff                 0    1072
# 87194ac15ffffff                 0     694
# ...                           ...     ...
# 87195daebffffff                 0    2731
# 87195daedffffff                 0    4644
# 87195daf3ffffff                 0     189
# 87195daf5ffffff                 0     548
# All                           420  305794
#
# [126 rows x 416 columns]

# %%
OD
# Out:
#            ORIGIN_CODE DESTINATION_CODE  FLOWS  origjob  origpop  destjobs  \
# 0      87194ac05ffffff  87194ac00ffffff    105      142    20963     268.0
# 1      87194ac05ffffff  87194ac01ffffff     42      142    20963     133.0
# 2      87194ac05ffffff  87194ac02ffffff      0      142    20963      94.0
# 3      87194ac05ffffff  87194ac03ffffff      0      142    20963      85.0
# 4      87194ac05ffffff  87194ac04ffffff    105      142    20963     272.0
# ...                ...              ...    ...      ...      ...       ...
# 51745  87195daf5ffffff  87195db5bffffff      0        8      170     218.0
# 51746  87195daf5ffffff  87195db5cffffff      0        8      170      10.0
# 51747  87195daf5ffffff  87195db5dffffff      0        8      170      23.0
# 51748  87195daf5ffffff  87195db69ffffff      0        8      170      24.0
# 51749  87195daf5ffffff  87195db6bffffff      0        8      170     160.0
#
#        destpop  TotalNoIntra  offset          Dist  log_destpop  log_destjobs  \
# 0        20981           105     0.0   2251.236531     9.951420      5.594711
# 1        20807            42     0.0   2275.632369     9.943093      4.897840
# 2        11696             0     0.0   4503.111326     9.367088      4.553877
# 3        16885             0     0.0   3819.612751     9.734240      4.454347
# 4        21207           105     0.0   2430.265954     9.962134      5.609472
# ...        ...           ...     ...           ...          ...           ...
# 51745    20305             0     0.0  16844.818926     9.918672      5.389072
# 51746     1447             0     0.0  19628.864700     7.277939      2.397895
# 51747    18468             0     0.0  20344.802842     9.823849      3.178054
# 51748     1980             0     0.0  29201.533495     7.591357      3.218876
# 51749    10793             0     0.0  26980.283813     9.286746      5.081404
#
#         log_Dist   O_i  D_j    alpha_i  prodsimest1
# 0       7.719679  1429  505  12.492951         89.0
# 1       7.730453  1429  147  12.492951         45.0
# 2       8.412746  1429  105  12.492951         10.0
# 3       8.248166  1429   42  12.492951         12.0
# 4       7.796167  1429  441  12.492951         79.0
# ...          ...   ...  ...        ...          ...
# 51745   9.731858   548  441  11.889060          1.0
# 51746   9.884807   548   21  11.889060          0.0
# 51747   9.920630   548   42  11.889060          0.0
# 51748  10.282011   548  232  11.889060          0.0
# 51749  10.202899   548  420  11.889060          0.0
#
# [51750 rows x 17 columns]

# %% [markdown]
# # Evaluation

# %%
def CalcRSquared(observed, estimated):
    """Calculate the r^2 from a series of observed and estimated target values
    inputs:
    Observed: Series of actual observed values
    estimated: Series of predicted values"""

    r, p = scipy.stats.pearsonr(observed, estimated)
    R2 = r **2

    return R2

def CalcRMSE(observed, estimated):
    """Calculate Root Mean Square Error between a series of observed and estimated values
    inputs:
    Observed: Series of actual observed values
    estimated: Series of predicted values"""

    res = (observed -estimated)**2
    RMSE = round(sqrt(res.mean()), 3)

    return RMSE

# %%
CalcRSquared(OD["FLOWS"], OD["prodsimest1"])
# Out:
# 0.655125413739805

# %%
CalcRMSE(OD["FLOWS"], OD["prodsimest1"])
# Out:
# 14.696

# %% [markdown]
# # **Save**

# %%
SIM_work  = OD[['ORIGIN_CODE', 'DESTINATION_CODE', 'prodsimest1']]
SIM_work.rename( columns= {'prodsimest1': 'flows'}, inplace=True )
SIM_work.to_csv(path + 'SIM_work.csv', index=False)

SIM_work
# Out:
# <ipython-input-45-7a0399456be4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SIM_work.rename( columns= {'prodsimest1': 'flows'}, inplace=True )
#            ORIGIN_CODE DESTINATION_CODE  flows
# 0      87194ac05ffffff  87194ac00ffffff   89.0
# 1      87194ac05ffffff  87194ac01ffffff   45.0
# 2      87194ac05ffffff  87194ac02ffffff   10.0
# 3      87194ac05ffffff  87194ac03ffffff   12.0
# 4      87194ac05ffffff  87194ac04ffffff   79.0
# ...                ...              ...    ...
# 51745  87195daf5ffffff  87195db5bffffff    1.0
# 51746  87195daf5ffffff  87195db5cffffff    0.0
# 51747  87195daf5ffffff  87195db5dffffff    0.0
# 51748  87195daf5ffffff  87195db69ffffff    0.0
# 51749  87195daf5ffffff  87195db6bffffff    0.0
#
# [51750 rows x 3 columns]
